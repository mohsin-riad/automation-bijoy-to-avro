# %% [markdown]
# # Bijoy to Unicode(Avro) Automation

# %%
# for one time installation
# !pip install bijoytounicode
# !pip install python-docx

# %%
import pandas as pd
from bijoytounicode import bijoy2unicode
import docx
import re  
import os

# %%
# apple script terminal executable
def runTerminal
# !textutil -convert docx *.doc

# %%
# To get the current working directory
# print(os.getcwd())
# tempPath = "/Users/mohsinriad/Documents/MyUniverse/ML-DL/Thesis/Datasets/untitled folder/C.R 153-18 08-07-2018.docx"

def convert(path):
    document =  docx.Document(path)
    for paragraph in document.paragraphs:
        print(bijoy2unicode(paragraph.text))

# %%
# path = "/Users/mohsinriad/Documents/MyUniverse/ML-DL/Thesis/Datasets/"

# %%
# files = os.listdir()

directory = '/Users/mohsinriad/Documents/MyUniverse/ML-DL/Thesis/Datasets/'
 
# iterate over files in
# that directory
for root, dirs, files in os.walk(directory):
    for filename in files:
#         print(os.path.join(root, filename))
        if filename.endswith(".doc"):
            
        if filename.endswith(".docx"):
            print("\n\n\n\n<<<<<---------------------------------------------------->>>>>>>\n\n\n\n")
            convert(os.path.join(root, filename))
# Out:
# <<<<<---------------------------------------------------->>>>>>>
#
#
#
#
# গণপ্রজাতন্ত্রী বাংলাদেশ সরকার
# চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট-এর কার্যালয়, চট্টগ্রাম।
# (প্রশাসনিক বিভাগ)
# স্মারক নং-         /সিএমএম(চট্টঃ)/প্রবি				  		 তারিখ ঃ
#
# প্রেরক ঃ চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট
# 	চট্টগ্রাম
# প্রাপক ঃ জেলা প্রশাসক
# ও
# সভাপতি
# জেলা আবাসন বোর্ড
# চট্টগ্রাম
# বিষয় ঃ	সরকারী বাসা বরাদ্দের দরখাস্ত অগ্রবর্তীকরণ প্রসঙ্গে।
# অত্র কার্যালয়ের রেকর্ড কীপার জনাব প্রশান্ত কুমার দাশ-এর বাসা বরাদ্দের স্বব্যাখ্যাত আবেদনপত্রটি অবগতি ও প্রয়োজনীয় ব্যবস্থা গ্রহণের নিমিত্ত সুপারিশসহ এতদ্‌সঙ্গে অগ্রবর্তী করা হল।
#
#
# (মোঃ শাহজাহান কবির)
# চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট
# চট্টগ্রাম।
# সংযুক্তি ঃ- বর্ণনা মোতাবেক ৩ ফর্দ্দ।
#
#
# বরাবর,
# 	জেলা প্রশাসক, চট্টগ্রাম।
# ও
# সভাপতি
# জেলা সরকারী আবাসন বোর্ড, চট্টগ্রাম।
#
# দৃষ্টি আকর্ষণ ঃ	উপ পরিচালক
# সরকারী আবাসন পরিদপ্তর
# আগ্রাবাদ, চট্টগ্রাম।
#
# মাধ্যম 	    ঃ	মাননীয় চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট,
# 		চট্টগ্রাম।
#
# বিষয় ঃ	আগ্রাবাদ জাম্বুরী মাঠ সরকারী (বহুতলা) কলোনীস্থ সি(এফ)-১২/১৭ অথবা ই ২/৭ নং বাসাটি খালি সাপেক্ষে বদলী বরাদ্দ প্রদানের আবেদন।
#
# মহোদয়,
# 	যথাযথ সম্মান প্রদর্শন পূর্বক বিনীত নিবেদন এই যে, আমি নিম্ন স্বাক্ষরকারী চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট কার্যালয়, চট্টগ্রাম- রেকর্ড কীপার পদে কর্মরত আছি। বিষয়ে বর্ণিত কলোনীতে আমার নামে বি ১৫/২১ নং বাসাটি বরাদ্দ সাপেক্ষে দীর্ঘদিন যাবৎ আমি আমার বৃদ্ধ পিতা, ছোট ভাই, স্ত্রী সন্তানাদি নিয়ে অনেক কষ্টে দিনযাপন করছি। বারংবার আবেদনের প্রেক্ষিতে সভায় সিদ্ধান্ত মোতাবেক সরকারী আবাসন পরিদপ্তর কার্যালয়ের স্মারকঃ নথি নং সি (এফ)-১৩/৭ বরাদ্দ/সআপচ/১৮২ তাং- ১৫/৪/১৪ খ্রিঃ আমার নামে উক্ত কলোনীতে সি(এফ)-১৩/৭ নং বাসাটি বরাদ্দ প্রদানে পত্র প্রাপ্ত হই। কিন্তু দুঃখের বিষয় বরাদ্দকৃত উক্ত বাসাটি বরাদ্দ প্রদানের পর হইতে এখন পর্যন্ত খালি হয় নাই বা হওয়ার সম্ভাবনাও নাই।
# আগ্রাবাদ জাম্বুরী মাঠ সরকারী (বহুতলা) কলোনী সি(এফ)-১২/১৭ নং বাসাটি পূর্বের বরাদ্দকৃত ব্যক্তি সরকারী আবাসন পরিদপ্তর কার্যালয়কে অবগত করে বাসাটি খালি করে কলোনী ত্যাগ করেন। অন্যদিকে ই ২/৭ নং বাসাটি ৩০ ডিসেম্বর/২০১৪ সালে চাকুরীর মেয়াদ শেষ হওয়ায় উক্ত বাসাটি জানুয়ারী/২০১৫ থেকে খালি হবে।
# অতএব, বিনীত প্রার্থনা জাম্বুরী মাঠ সরকারী (বহুতলা) কলোনী সি (এফ) ১২/১৭ অথবা ই ২/৭ নং বাসাটি আমার নামে বরাদ্দ প্রদানে মহোদয়ের যেন সদয় আজ্ঞা হয়।
#
# বিনীত নিবেদক
#
#  (প্রশান্ত কুমার দাশ)
# রেকর্ড কীপার
# চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট-এর কার্যালয়
# চট্টগ্রাম।
#
# বরাবর,
# 	জেলা প্রশাসক, চট্টগ্রাম।
# ও
# সভাপতি
# জেলা সরকারী আবাসন বোর্ড, চট্টগ্রাম।
#
# দৃষ্টি আকর্ষণ ঃ	উপ পরিচালক
# জেলা সরকারী আবাসন পরিদপ্তর
# আগ্রাবাদ, চট্টগ্রাম।
#
# মাধ্যম 	    ঃ	মাননীয় চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট,
# 		চট্টগ্রাম।
#
# বিষয় ঃ	আগ্রাবাদ জাম্বুরী মাঠ সরকারী (বহুতলা) কলোনীস্থ ই ২/৭ নং বাসাটি খালি সাপেক্ষে বদলী বরাদ্দ প্রদানের আবেদন।
#
# মহোদয়,
# 	যথাযথ সম্মান প্রদর্শন পূর্বক বিনীত নিবেদন এই যে, আমি নিম্ন স্বাক্ষরকারী চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট কার্যালয়, চট্টগ্রাম- রেকর্ড কীপার পদে কর্মরত আছি। আগ্রাবাদ জাম্বুরী মাঠ সরকারী (বহুতলা) কলোনীতে আমার নামে এফ ১৩/৭ নং বাসাটি বরাদ্দ রহিয়াছে যাহাতে ভাই বোন, স্ত্রী, সন্তানাদি নিয়ে অনেক কষ্টে দিনাতিপাত করতে হয়। বিষয়ে বর্ণিত বাসাটি পূর্বে বরাদ্দকৃত প্রাপ্ত ব্যক্তির বিগত ৩০শে ডিসেম্বর'২০১৪ সালে চাকুরীর মেয়াদ শেষ হওয়ায় এবং তাহার পি আর এল ভোগের সুবিধা না থাকায় বিগত ১১/১২/২০১৪ ইং তারিখে উক্ত বাসাটি আমার নামে বরাদ্দ হওয়ার জন্য একখানা আবেদন করি। কিন্তু দুঃখের বিষয় অদ্যাবধি পর্যন্ত উক্ত বাসাটি কাহাকেও বরাদ্দ প্রদান করা হয়নি।
# অতএব, বিনীত প্রার্থনা, জাম্বুরী মাঠ সরকারী (বহুতলা) কলোনী ই ২/৭ নং বাসাটি আমার নামে বরাদ্দ প্রদানে মহোদয়ের যেন সদয় আজ্ঞা হয়।
#
# বিনীত নিবেদক
#
#  (প্রশান্ত কুমার দাশ)
# রেকর্ড কীপার
# চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট-এর কার্যালয়
# চট্টগ্রাম।
#
# সংযুক্ত ঃ-	বিগত ১১/১২/২০১৪ ইং তারিখে বর্ণিত বাসাটির বরাদ্দ প্রদানের আবেদনপত্র (ফটোকপি ১ সেট)।
#
# বরাবর,
# 	জেলা প্রশাসক, চট্টগ্রাম।
# ও
# সভাপতি
# জেলা সরকারী আবাসন বোর্ড, চট্টগ্রাম।
#
# দৃষ্টি আকর্ষণ ঃ	উপ পরিচালক
# জেলা সরকারী আবাসন পরিদপ্তর
# আগ্রাবাদ, চট্টগ্রাম।
#
#
# বিষয় ঃ	আগ্রাবাদ জাম্বুরী মাঠ সরকারী (বহুতলা) কলোনীস্থ ই ২/৭ নং বাসাটি খালি সাপেক্ষে বদলী বরাদ্দ প্রদানের আবেদন।
#
# মহোদয়,
# 	যথাযথ সম্মান প্রদর্শন পূর্বক বিনীত নিবেদন এই যে, আমি নিম্ন স্বাক্ষরকারী চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট কার্যালয়, চট্টগ্রাম- রেকর্ড কীপার পদে কর্মরত আছি। আগ্রাবাদ জাম্বুরী মাঠ সরকারী (বহুতলা) কলোনীতে আমার নামে এফ ১৩/৭ নং বাসাটি বরাদ্দ রহিয়াছে যাহাতে ভাই বোন, স্ত্রী, সন্তানাদি নিয়ে অনেক কষ্টে দিনাতিপাত করতে হয়। বিষয়ে বর্ণিত বাসাটি পূর্বে বরাদ্দকৃত প্রাপ্ত ব্যক্তির বিগত ৩০শে ডিসেম্বর'২০১৪ সালে চাকুরীর মেয়াদ শেষ হওয়ায় এবং তাহার পি আর এল ভোগের সুবিধা না থাকায় বিগত ১১/১২/২০১৪ ইং তারিখে উক্ত বাসাটি আমার নামে বরাদ্দ হওয়ার জন্য একখানা আবেদন করি। কিন্তু দুঃখের বিষয় অদ্যাবধি পর্যন্ত উক্ত বাসাটি কাহাকেও বরাদ্দ প্রদান করা হয়নি।
# অতএব, বিনীত প্রার্থনা, জাম্বুরী মাঠ সরকারী (বহুতলা) কলোনী ই ২/৭ নং বাসাটি আমার নামে বরাদ্দ প্রদানে মহোদয়ের যেন সদয় আজ্ঞা হয়।
#
# বিনীত নিবেদক
#
#  (প্রশান্ত কুমার দাশ)
# রেকর্ড কীপার
# চীফ মেট্রোপলিটন ম্যাজিস্ট্রেট-এর কার্যালয়
# চট্টগ্রাম।
#
# সংযুক্ত ঃ-	বিগত ১১/১২/২০১৪ ইং তারিখে বর্ণিত বাসাটির বরাদ্দ প্রদানের আবেদনপত্র (ফটোকপি ১ সেট)।
#
#
#
#
# <<<<<---------------------------------------------------->>>>>>>
#
#
#
#
# মাননীয়,
# ৫ম সিনিয়র সহকারী জজ আদালত, চট্টগ্রাম।
#
# সূত্র ঃ এ্যাক্ট-৮(অপঃ-ঠওওও) মামলা নং- ৩২৭/২০১৬।
# অনুমতি মিছ মামলা নং-      /২০২০ ইংরেজী।
#
# মোছাঃ রম্নবি আকতার, স্বামী- মরহুম নুরম্নল আমিন, সাং- ২৩৬, আমিন সেন্টার, মোহাম্মদনগর, ডাকঘর- আমিন জুট মিলস, থানা- বায়েজিদ বোস্তামী, জেলা- চট্টগ্রাম।
# বর্তমানে- এ.আর.ম্যানসন, রোড নং- ১, বাড়ী নং- ১৬, মোহাম্মদ নগর, ডাকঘর- আমিন জুট মিলস, থানা- বায়েজিদ বোস্তামী, জেলা- চট্টগ্রাম।
# ====== প্রাথীর্ক।
# বিষয়ঃ প্রাথীর্ক পেÿ অত্র মামলার মূল নথি মহাফেজ খানা হইতে তলব (ঈধষষ ঋড়ৎ) করার প্রার্থনা।
#
# উপরোক্ত প্রাথীর্ক নিম্ন মতে নিবেদন করেন,
# ১।	অত্র মামলায় এই প্রার্থীক পÿ বিগত ১৬/১০/২০১৬ ইংরেজী পারিবারিক মামলা নং- অপঃ ঠওওও ৩২৭/১৬ ইং দায়ের করিয়া বিগত ০৫/০১/২০১৭ ইংরেজী তারিখ নাবালক নাবালিকাগণের পেÿ অভিভাবিকা নিযুক্ত হন। অদ্য এই প্রাথীর্ক নাবালক-নাবালিকাগণের উক্ত মামলার সম্পত্তির তৎ পিতার বিগত ৩০/০৩/২০১৬ ইং তারিখের ৪৯০৮নং আমমোক্তারনামা দলিল রহিত বা বাতিল করন দলিল রেজিষ্ট্রি করার প্রার্থনা করিয়া মিছ মামলা নং-           /২০২০ ইংরেজী দায়ের করিয়াছেন। উক্ত মামলা শুনানীর জন্য অত্র মামলায় নথি উপস্থাপন করা একান্ত আবশ্যক। তাই মহাফেজ খানা হইতে অত্র মামলার নথি তলব (ঈধষষ ভড়ৎ) করা একান্ত আবশ্যক। নচেৎ এই প্রাথীর্কের অপূরণীয় ÿতির কারন হইবে।
# অতএব বিনীত প্রার্থনা উপরোক্ত হেতুতে অত্র মামলার মূল নথি মহাফেজ খানা হইতে তলব (ঈধষষ ভড়ৎ) করার আদেশ দানে হুজুরের বিহীত মর্জি হয়।
# তারিখঃ- ১৩/০৭/২০২০ ইংরেজী।
#
#
#
#
# রওশন আরা (৪৫), স্বামী- মৃত মোহাম্মদ ছৈয়দ, মাতা- মাজমা খাতুন, সাং- শিকলবাহা (আহছানিয়া পাড়া), অছি মিয়ার বাড়ী, ডাকঘর- শিকলবাহা (মাষ্টার হাট), থানা- কর্ণফুলী, জেলা- চট্টগ্রাম।
# ------- প্রাথীর্ক।
# উপরোক্ত প্রাথীর্কের বিনীত নিবেদন এই যে,
# ১।	উলেস্নখিত প্রাথীর্কের স্বামী মৃত মোহাম্মদ ছৈয়দ বিগত ২০/০৪/২০১০ ইং তারিখে মৃতু্যবরণ করেন। তাহাকে যথাযথ ধমীর্য় মযার্দায় পারিবারিক কবরস্থানে দাফন করা হয়।
# ২।	উক্ত মৃত মোহাম্মদ ছৈয়দ নিম্ন লিখিত দেরকে তাহার বৈধ ও আইনগত ওয়ারিশ হিসাবে রাখিয়া যান।
#
# ৩।	উলেস্নখিত মৃত মোহাম্মদ ছৈয়দ নিম্নোক্তকে তাহার নিকটতম আত্মীয় হিসাবে রাখিয়া যান।
# চলমান পাতা-০২
# পাতা-০২
# 	আবু সৈয়দ, পিতা- মৃত আবদুল গনি, সাং- শিকলবাহা, আহছানিয়া পাড়া, অছিমিয়ার বাড়ী, ডাকঘর- শিকলবাহা (মাষ্টার হাট), থানা- কর্ণফুলী, জেলা- চট্টগ্রাম।                    ===== সর্ম্পকে- মৃত ব্যক্তির ভ্রাতা।
# ৪।	নিম্ন তফসিলোক্ত সম্পত্তি বি.এস ২০৫নং খতিয়ানের রেকডীর্য় মালিক হাকিম জান হইতে ০৮/০৮/১৯৯২ ইং তারিখের ৫০৩৭নং কবলা মূলে লায়লা খাতুন খরিদ করিয়া দখল মালিক স্বত্ববান থাকাবস্থায় বিগত ১৬/০৩/২০০৩ ইং তারিখে ১৩৬৮নং রেজিষ্ট্রিযুক্ত দলিল মূলে প্রাথীর্কের স্বামী মৃত মোহাম্মদ ছৈয়দ ১ গন্ডা বা ২ শতক বা ০২০০ শতাংশ সম্পত্তি ক্রয় করিয়া তাহার নামে বি.এস নামজারী খতিয়ান ১০১৬ সৃজন করিয়া সকলের জ্ঞাতসারে ভোগ দখলে থাকাবস্থায় মৃতু্যবরণ করার সময় এক স্ত্রী রোওশন আরা, দুই পুত্র যথাক্রমে মামুনুর রশিদ, মোঃ শাহীন আলম ও এক কন্যা পাড়ীয়া সুলতানাকে ওয়ারিশ রাখিয়া যান। তৎ মতে প্রাথীর্নি, তাহার নাবালিকা কন্যা সন্তান অধীন প্রাথীর্নির তত্ত্বাবধানে বসবাস করিতেছেন।
# ৫।	প্রার্থীকের স্বামীর ত্যাজ্য বিত্ত মোট ০২০০ শতাংশ সম্পত্তি হইতে মরহুমের স্ত্রী হিসাবে প্রাথীর্ক অংশ বা ০০২৫ শতাংশ পুত্র মামুনুর রশিদ অংশ বা ০০৭০ শতাংশ মোঃ শাহীন আলম  অংশ বা ০০৭০ শতাংশ নাবালিকা এক কন্যা পাড়ীয়া সোলতানা অংশ বা ০০৩৫ শতাংশ সম্পত্তি প্রাপ্ত হন।
# ৬।	প্রাথীর্কের স্বামীর খরিদা সূত্রে প্রাপ্ত নিম্ন বর্ণিত তপশীলের সম্পত্তিতে প্রাথীর্কের একমাত্র কন্যা নাবালিকা থাকায় নাবালিকার অংশের যাবতীয় শাসন সংরÿণ এবং নাবালিকার পেÿ ব্যয় বিক্রী, হস্তান্তর ও বন্ধক প্রদান ইত্যাদি করনের নিমিত্তে অভিভাবক সনদ পত্র প্রাপ্তী লাভ করা একান্ত আবশ্যক।
# পাতা-০৩
# ৬।	প্রাথীর্ক নাবালিকার স্বাভাবিক অভিভাবক হওয়া সত্ত্বেও তপশীলোক্ত সম্পত্তি সর্ম্পকে নাবালিকার প্রাপ্য অংশে যাবতীয় শাসন সংরÿণ এবং ব্যয়, বিক্রি, হস্তান্তর ও বন্ধকি প্রদান ইত্যাদির জন্য আদালতের অনুমতি সাপেেÿ অভিভাবক সনদ প্রাপ্তির প্রার্থনায় মাননীয় আদালতের শরণাপন্ন হইলেন।
# ৭।	প্রাথীর্ক বিজ্ঞ আদালত ব্যতিত অন্য কোন আদালতে অত্র নাবালিকার অভিভাবক সনদ প্রাপ্তির জন্য কোন মামলা আনয়ন করেন নাই।
# অতএব মহোদয় প্রাথীর্কের আবেদন গ্রহনে নিম্ন বর্ণিত তপশীলের সম্পত্তিতে নাবালিকার প্রাপ্য অংশের উপর যাবতীয় শাসন সংরÿণ এবং ব্যয়, বিক্রি, হস্তান্তর ও বন্ধকী প্রদানে অনুমতি প্রদান সাপেেÿ প্রাথীর্কের বরাবরে অভিভাবক সনদ প্রদানে বিহীত আজ্ঞা হয়।
# তপশীল
# জেলা- চট্টগ্রাম, থানা- বন্দর, মেজৗা- চরপাথরঘাটা আর.এস খতিয়ান ১১০ আর.এস দাগ নং- ১২৩৭, তৎ সামিল বি.এস জরিপের ২০৫নং খতিয়ানের বি.এস নামজারী ১০১৬নং খতিয়ানের বি.এস ১২২৫ (এক হাজার দুইশত পঁচিশ) দাগের ০২০০ শতাংশের আন্দরে নাল সম্পত্তিতে নাবালিকার অংশ ০০৩৫ শতাংশ।
# সংযুক্তি ঃ-
# ১। মৃতু্যসনদ পত্র।
# ২। ওয়ারিশ সনদপত্র।
# ৩। বি.এস নামজারী খতিয়ানের ফটোকপি।
# ৪। জন্ম সনদ ও আইডি কার্ডের ফটোকপি।
#
# শপথনামা
#
# 	আমি রওশন আরা, স্বামী- মৃত মোহাম্মদ ছৈয়দ, মাতা- মাজমা খাতুন, সাং- শিকলবাহা (আহছানিয়া পাড়া), অছি মিয়ার বাড়ী, ডাকঘর- শিকলবাহা (মাষ্টার হাট), থানা- কর্ণফুলী, জেলা- চট্টগ্রাম, বয়স- ৪৫ বৎসর, ধর্ম- ইসলাম, পেশা- গৃহিনী, জাতীয়তা- বাংলাদেশী এই মর্মে শপথ পূর্বক ঘোষণা করিতেছি যে,
# (১)	অত্র দরখাস্তে যাহা লিপি করা হইয়াছে তাহা আমার জ্ঞান ও বিশ্বাস মতে সত্য।
# (২)	আমি অত্র মামলার প্রাথীর্ক হিসাবে অত্র হলফনামা প্রদানে উপযুক্ত হই।
# সত্যপাঠ
# অত্র হলফনামায় যাহা লিপি করা হইয়াছে তাহা আমার জ্ঞান ও বিশ্বাসমতে সত্য জানিয়া অদ্য    /১১/২০১৯ ইং তারিখ বেলা ১০.৩০ মিনিটের সময় আদালতে উপস্থিত হইয়া অত্র সত্য পাঠে নিজ নাম দস্তখত করিয়া দিলাম।
#
# (হলফকারীর স্বাক্ষর)
# অত্র হলফকারী আমার পরিচিত। তিনি অদ্য অত্র আদালতে হাজির হইয়া আমার সন্মুখে তাহার নিজ নাম স্বাক্ষর করিলেন। মামলা চলাকালীন সময়ে আমি তাহার পক্ষ সমর্থন করিব। আমি তাহাকে সনাক্ত করিলাম।
#
# (এডভোকেট)
